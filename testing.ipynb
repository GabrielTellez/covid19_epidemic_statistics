# %%
import covid19_epidemics_tools as cet
# Out:
# Importing https://pkgstore.datahub.io/core/covid-19/countries-aggregated_csv/data/ca94698cd625423ee29baa35c658631d/countries-aggregated_csv.csv

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
cet.plotdata();
# Out:
# <img src="data:image/png;base64,..." width="950">
# US not in quarantine

# %%
figc100=cet.plotdata(minindicator=100)
# Out:
# <img src="data:image/png;base64,..." width="950">
# US not in quarantine

# %%
figd10=cet.plotdata(indicator='Deaths', minindicator=10)
# Out:
# <img src="data:image/png;base64,..." width="950">
# Colombia quarantine date 2020-03-24 out of bounds. Day zero is 2020-03-29
# US not in quarantine

# %%
cet.plotdata(indicator='Deaths', minindicator=10, logscale=False);
# Out:
# <img src="data:image/png;base64,..." width="950">
# Colombia quarantine date 2020-03-24 out of bounds. Day zero is 2020-03-29
# US not in quarantine

# %%
cet.plotdata(indicator='Deaths', minindicator=1);
# Out:
# <img src="data:image/png;base64,..." width="950">
# US not in quarantine

# %%
figd10
# Out:
# <img src="data:image/png;base64,..." width="950">

# %%
figc100
# Out:
# <img src="data:image/png;base64,..." width="950">

# %%
cet.plotdata(countrylist=cet.defaultcountrylist+('Spain','China'),minindicator=100);
# Out:
# <img src="data:image/png;base64,..." width="950">
# US not in quarantine

# %%
cet.plotdata(countrylist=cet.defaultcountrylist+('Spain','China'),minindicator=500);
# Out:
# <img src="data:image/png;base64,..." width="950">
# Colombia quarantine date 2020-03-24 out of bounds. Day zero is 2020-03-27
# US not in quarantine

# %%
cet.plotdata(countrylist=cet.defaultcountrylist+('Spain','China'),indicator='Deaths',minindicator=10);
# Out:
# <img src="data:image/png;base64,..." width="950">
# Colombia quarantine date 2020-03-24 out of bounds. Day zero is 2020-03-29
# US not in quarantine

# %%
cet.plotdata(show='Recovered');
# Out:
# <img src="data:image/png;base64,..." width="950">
# US not in quarantine

# %%
cet.plotdata(indicator='Confirmed',minindicator=100,show='Recovered');
# Out:
# <img src="data:image/png;base64,..." width="950">
# US not in quarantine

# %%
cet.plotdata(indicator='Confirmed',minindicator=100,show='Deaths');
# Out:
# <img src="data:image/png;base64,..." width="950">
# US not in quarantine

# %%
cet.builddatalist(indicator='Date',minindicator='2020-01-01')
# Out:
# {'Colombia':              Date   Country  Confirmed  Recovered  Deaths  Day
#  37     2020-01-22  Colombia          0          0       0    0
#  222    2020-01-23  Colombia          0          0       0    1
#  407    2020-01-24  Colombia          0          0       0    2
#  592    2020-01-25  Colombia          0          0       0    3
#  777    2020-01-26  Colombia          0          0       0    4
#  ...           ...       ...        ...        ...     ...  ...
#  14282  2020-04-08  Colombia       2054        123      54   77
#  14467  2020-04-09  Colombia       2223        174      69   78
#  14652  2020-04-10  Colombia       2473        197      80   79
#  14837  2020-04-11  Colombia       2709        214     100   80
#  15022  2020-04-12  Colombia       2776        270     109   81
#
#  [82 rows x 6 columns],
#  'Italy':              Date Country  Confirmed  Recovered  Deaths  Day
#  84     2020-01-22   Italy          0          0       0    0
# ...

# %%
cet.plotdata(indicator='Date',minindicator='2020-01-01',show='Confirmed');
# Out:
# <img src="data:image/png;base64,..." width="950">
# US not in quarantine

# %%
cet.builddatalist()
# Out:
# {'Colombia':              Date   Country  Confirmed  Recovered  Deaths  Day
#  8177   2020-03-06  Colombia          1          0       0    0
#  8362   2020-03-07  Colombia          1          0       0    1
#  8547   2020-03-08  Colombia          1          0       0    2
#  8732   2020-03-09  Colombia          1          0       0    3
#  8917   2020-03-10  Colombia          3          0       0    4
#  9102   2020-03-11  Colombia          9          0       0    5
#  9287   2020-03-12  Colombia          9          0       0    6
#  9472   2020-03-13  Colombia         13          0       0    7
#  9657   2020-03-14  Colombia         22          0       0    8
#  9842   2020-03-15  Colombia         34          0       0    9
#  10027  2020-03-16  Colombia         54          0       0   10
#  10212  2020-03-17  Colombia         65          1       0   11
#  10397  2020-03-18  Colombia         93          1       0   12
# ...

# %%
cet.builddatalist(showtype='toto')
# Out:
# {'Colombia':              Date   Country  Confirmed  Recovered  Deaths  Day
#  8177   2020-03-06  Colombia          1          0       0    0
#  8362   2020-03-07  Colombia          1          0       0    1
#  8547   2020-03-08  Colombia          1          0       0    2
#  8732   2020-03-09  Colombia          1          0       0    3
#  8917   2020-03-10  Colombia          3          0       0    4
#  9102   2020-03-11  Colombia          9          0       0    5
#  9287   2020-03-12  Colombia          9          0       0    6
#  9472   2020-03-13  Colombia         13          0       0    7
#  9657   2020-03-14  Colombia         22          0       0    8
#  9842   2020-03-15  Colombia         34          0       0    9
#  10027  2020-03-16  Colombia         54          0       0   10
#  10212  2020-03-17  Colombia         65          1       0   11
#  10397  2020-03-18  Colombia         93          1       0   12
# ...

# %%
help(cet.builddatalist)
# Out:
# Help on function builddatalist in module covid19_epidemics_tools:
#
# builddatalist(indicator='Confirmed', minindicator=1, show=None, showtype='cumulative', countrylist=('Colombia', 'Italy', 'US'), fulldata=             Date             Country  Confirmed  Recovered  Deaths
# 0      2020-01-22         Afghanistan          0          0       0
# 1      2020-01-22             Albania          0          0       0
# 2      2020-01-22             Algeria          0          0       0
# 3      2020-01-22             Andorra          0          0       0
# 4      2020-01-22              Angola          0          0       0
# ...           ...                 ...        ...        ...     ...
# 15165  2020-04-12  West Bank and Gaza        290         58       2
# 15166  2020-04-12      Western Sahara          6          0       0
# 15167  2020-04-12               Yemen          1          0       0
# 15168  2020-04-12              Zambia         43         30       2
# ...

# %%
cet.builddatalist(showtype='daily increase')
# Out:
# {'Colombia':              Date   Country  Confirmed  Recovered  Deaths  \
#  8177   2020-03-06  Colombia          1          0       0
#  8362   2020-03-07  Colombia          1          0       0
#  8547   2020-03-08  Colombia          1          0       0
#  8732   2020-03-09  Colombia          1          0       0
#  8917   2020-03-10  Colombia          3          0       0
#  9102   2020-03-11  Colombia          9          0       0
#  9287   2020-03-12  Colombia          9          0       0
#  9472   2020-03-13  Colombia         13          0       0
#  9657   2020-03-14  Colombia         22          0       0
#  9842   2020-03-15  Colombia         34          0       0
#  10027  2020-03-16  Colombia         54          0       0
#  10212  2020-03-17  Colombia         65          1       0
#  10397  2020-03-18  Colombia         93          1       0
#  10582  2020-03-19  Colombia        102          1       0
#  10767  2020-03-20  Colombia        128          1       0
# ...

# %%
cet.builddatalist(show='Deaths', showtype='Daily percentage increase')
# Out:
# {'Colombia':              Date   Country  Confirmed  Recovered  Deaths  Day
#  8177   2020-03-06  Colombia          1          0       0    0
#  8362   2020-03-07  Colombia          1          0       0    1
#  8547   2020-03-08  Colombia          1          0       0    2
#  8732   2020-03-09  Colombia          1          0       0    3
#  8917   2020-03-10  Colombia          3          0       0    4
#  9102   2020-03-11  Colombia          9          0       0    5
#  9287   2020-03-12  Colombia          9          0       0    6
#  9472   2020-03-13  Colombia         13          0       0    7
#  9657   2020-03-14  Colombia         22          0       0    8
#  9842   2020-03-15  Colombia         34          0       0    9
#  10027  2020-03-16  Colombia         54          0       0   10
#  10212  2020-03-17  Colombia         65          1       0   11
#  10397  2020-03-18  Colombia         93          1       0   12
# ...

# %%
cet.plotdata(showtype='daily increase',logscale=False);
# Out:
# <img src="data:image/png;base64,..." width="950">
# US not in quarantine

# %%
cet.plotdata(showtype='daily increase',logscale=False, countrylist=('Colombia',));
# Out:
# <img src="data:image/png;base64,..." width="950">

# %%
cet.plotdata(showtype='daily increase',logscale=True, countrylist=('US',));
# Out:
# <img src="data:image/png;base64,..." width="950">
# US not in quarantine

# %%
cet.plotdata(showtype='daily increase',logscale=False, countrylist=('US',));
# Out:
# <img src="data:image/png;base64,..." width="950">
# US not in quarantine

# %%
cet.plotdata(showtype='daily increase',logscale=False, countrylist=('Italy',));
# Out:
# <img src="data:image/png;base64,..." width="950">

# %%
cet.plotdata(showtype='daily increase',logscale=False, countrylist=('China',));
# Out:
# <img src="data:image/png;base64,..." width="950">

# %%
cet.plotdata(showtype='daily percentage increase',logscale=False);
# Out:
# <img src="data:image/png;base64,..." width="950">
# US not in quarantine

# %%
cet.plotdata(showtype='daily increase',logscale=False, countrylist=('US',), indicator='Deaths');
# Out:
# <img src="data:image/png;base64,..." width="950">
# US not in quarantine

# %%
cet.plotdata(showtype='daily increase',logscale=True, countrylist=('US',), indicator='Deaths');
# Out:
# <img src="data:image/png;base64,..." width="950">
# US not in quarantine

# %%
cet.plotdata(showtype='daily increase',logscale=False, countrylist=('Italy',), indicator='Deaths');
# Out:
# <img src="data:image/png;base64,..." width="950">

# %%
cet.plotdata(showtype='daily increase', indicator='Deaths');
# Out:
# <img src="data:image/png;base64,..." width="950">
# US not in quarantine

# %%
cet.plotdata(showtype='daily increase', indicator='Deaths',minindicator=10);
# Out:
# <img src="data:image/png;base64,..." width="950">
# Colombia quarantine date 2020-03-24 out of bounds. Day zero is 2020-03-29
# US not in quarantine

# %%
cet.plotdata(showtype='daily increase', indicator='Deaths',countrylist=('Colombia',), logscale=False);
# Out:
# <img src="data:image/png;base64,..." width="950">

# %%
cet.plotdata( indicator='Deaths',countrylist=('Colombia',), logscale=False);
# Out:
# <img src="data:image/png;base64,..." width="950">

# %%
cet.plotdata( indicator='Deaths',countrylist=('Colombia',), logscale=True);
# Out:
# <img src="data:image/png;base64,..." width="950">

# %%
cet.plotdata( indicator='Deaths',countrylist=('Colombia',), logscale=True);
# Out:
# <img src="data:image/png;base64,..." width="950">
